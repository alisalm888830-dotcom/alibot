# %% [markdown]
# <a href="https://colab.research.google.com/github/alisalm888830-dotcom/alibot/blob/main/%D8%AA%D9%87%D9%86%D8%A6%D8%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import HTML, display
import time

# تهنئة ملونة ومتحركة
تهنئة_HTML = HTML("""
<div style="
    background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
    padding: 30px;
    border-radius: 20px;
    text-align: center;
    font-family: 'Courier New', monospace;
    animation: fadeIn 2s;
">
    <h1 style="color: white;">🎊 ألف مبروك يا أستاذي! 🎊</h1>
    <h2 style="color: #ffd700;">☁️ قسم الامن السيبرني الحوسبة السحابية - العملي ☁️</h2>
    <hr style="border-color: white;">
    <p style="color: white; font-size: 18px;">
        🚀 <strong>HTTP GET</strong> → تهنئة من قلبي<br>
        📦 <strong>S3 Bucket</strong> → مليان دعوات حلوة<br>
        💻 <strong>EC2 Instance</strong> → العزوبية توقفت نهائيًا<br>
    </p>
    <hr style="border-color: white;">
    <h3 style="color: #ffd700;">🎉 من طالب يحبك ويتمنى لك كل السعادة 🎉</h3>
    <p style="color: white;">✨ عقبال ما تشوفني مهندس سحابات مثلك ✨</p>
</div>

<style>
@keyframes fadeIn {
    from { opacity: 0; transform: scale(0.9); }
    to { opacity: 1; transform: scale(1); }
}
</style>
""")

# عرض التهنئة
display(تهنئة_HTML)
# Out:
# <div style="
#     background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#     padding: 30px;
#     border-radius: 20px;
#     text-align: center;
#     font-family: 'Courier New', monospace;
#     animation: fadeIn 2s;
# ">
#     <h1 style="color: white;">🎊 ألف مبروك يا أستاذي! 🎊</h1>
#     <h2 style="color: #ffd700;">☁️ قسم الامن السيبرني الحوسبة السحابية - العملي ☁️</h2>
#     <hr style="border-color: white;">
#     <p style="color: white; font-size: 18px;">
#         🚀 <strong>HTTP GET</strong> → تهنئة من قلبي<br>
#         📦 <strong>S3 Bucket</strong> → مليان دعوات حلوة<br>
#         💻 <strong>EC2 Instance</strong> → العزوبية توقفت نهائيًا<br>
#     </p>
#     <hr style="border-color: white;">
#     <h3 style="color: #ffd700;">🎉 من طالب يحبك ويتمنى لك كل السعادة 🎉</h3>
#     <p style="color: white;">✨ عقبال ما تشوفني مهندس سحابات مثلك ✨</p>
# </div>
#
# <style>
# @keyframes fadeIn {
#     from { opacity: 0; transform: scale(0.9); }
# ...
